# %%
from enum import Enum
from typing import Dict, List
from patchright.async_api import async_playwright
from lxml import html
import asyncio
from abc import ABC, abstractmethod

# %%
async def scroll_to_bottom(page, scroll_delay=0.25):
    """
    Scroll to the bottom of the page iteratively, with delays to ensure dynamic content is fully loaded.
    
    Args:
        page: The Playwright page instance.
        scroll_delay: Delay in seconds between scrolls to allow content loading.
    """
    previous_height = 0
    next_scroll = 500
    for i in range(10):
        # Scroll 500 pixels at a time
        await page.evaluate(f"window.scrollTo(0, {next_scroll})")
        next_scroll += 1000

        # Wait for content to load
        await asyncio.sleep(scroll_delay)

        # Measure the new scroll height
        current_height = await page.evaluate("document.body.scrollHeight")

        # If no new content is loaded, stop scrolling
        if current_height == previous_height:
            pass
            # break
        previous_height = current_height

# %%
class WebsiteInterface(ABC):
    def __init__(self):
        self.base_url = ""

    @abstractmethod
    async def crawl(self) -> List[Dict[str, str]]:
        """
        Abstract method to crawl the website and extract listings.
        Must be implemented by subclasses.
        """
        pass

    @abstractmethod
    def get_filters_info(self) -> str:
        """
        Abstract method to return a prompt for the LLM describing the filters and expected output format.
        Must be implemented by subclasses.
        """
        pass

    @abstractmethod
    def set_filters_from_llm_response(self, llm_response: str):
        """
        Abstract method to process the LLM's response and set the URL with appropriate filters.
        Must be implemented by subclasses.
        """
        pass

class AutotraderInterface(WebsiteInterface):
    class ListingType(Enum):
        NEW = "NEW"
        USED = "USED"
        CERTIFIED = "CERTIFIED"
        TP_CERT = "3P_CERT" # Third-party certified
    
    def __init__(self):
        self.base_url = "https://www.autotrader.com/cars-for-sale/all-cars"
        # https://www.autotrader.com/cars-for-sale/all-cars/floral-park-ny?endYear=2022&makeCode=BMW&makeCode=FORD&newSearch=true&startYear=2012&zip=11001

        # All the filters are search parameters in the URL
        self.filters = {
            "zip": int,
            "startYear": int,
            "endYear": int,
            "makeCode": str,  # Can appear multiple times
            "listingType": AutotraderInterface.ListingType, # Can appear multiple times
            "mileage": int,
        }
        
    async def crawl(self) -> List[Dict[str, str]]:
        listings = []
        
        url = self.url

        async with async_playwright() as p:
            # Launch browser in headless mode
            browser = await p.chromium.launch(headless=True,
                                                args=[
                                                    "--disable-blink-features=AutomationControlled",
                                                    "--disable-extensions",
                                                    "--disable-infobars",
                                                    "--enable-automation",
                                                    "--no-first-run",
                                                    "--enable-webgl",
                                                ])
            
            context = await browser.new_context(
                user_agent='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
                viewport={"width": 1920, "height": 1080},
                locale="en-US",
                timezone_id="Europe/Paris",
                java_script_enabled=True,
            )

            # Modify navigator properties to hide automation
            page = await context.new_page()
            
            await page.goto(url)
            
            # If "This site asks for consent to use your data" is present in the page, click on "Consent" button with class "fc-button fc-cta-consent fc-primary-button"
            try:
                await page.click('text="Consent"')
            except:
                pass
            
            # Scroll to the bottom of the page
            await scroll_to_bottom(page)
            
            page_content = await page.content()
            
            # Parse HTML using lxml
            tree = html.fromstring(page_content)

            # XPath to select each car listing container
            listings_elements = tree.xpath('//div[@data-cmp="inventoryListing"]')

            listings = []

            for listing in listings_elements:
                car_data = {}
                # Extract car details
                car_data['title'] = listing.xpath('.//h2[@data-cmp="subheading"]/text()')
                car_data['url'] = listing.xpath('.//a[@data-cmp="link"]/@href')
                car_data['mileage'] = listing.xpath('.//div[@data-cmp="mileageSpecification"]/text()')
                car_data['price'] = listing.xpath('.//div[@data-cmp="firstPrice"]/text()')
                car_data['dealer'] = listing.xpath('.//div[@class="text-subdued"]/text()')
                car_data['phone'] = listing.xpath('.//span[@data-cmp="phoneNumber"]/text()')
                car_data['image'] = listing.xpath('.//img[@data-cmp="inventoryImage"]/@src')

                # Clean up extracted data
                car_data = {key: (val[0].strip() if val else None) for key, val in car_data.items()}
                listings.append(car_data)
                
            if __name__ == "__main__":
                print("Found the following car listings:")
                # Display the extracted data
                for car in listings:
                    print(car)

            await browser.close()
        
        return listings
    
    def get_filters_info(self) -> str:
        """
        Return a prompt for the LLM describing the filters and expected output format.
        """
        return f"""
        You are a helpful assistant that translates user requirements into a URL with query parameters.

        The base URL is: {self.base_url}
        Filters:
        - zip: User's zip code (integer, required).
        - startYear: Minimum year of the car (integer).
        - endYear: Maximum year of the car (integer).
        - makeCode: Car manufacturer code (string, can appear multiple times).
        - listingType: Type of listing (one of {', '.join([e.value for e in self.ListingType])}).
        - mileage: Maximum mileage of the car (integer).

        Example Output:
        A complete URL with query parameters, e.g.,:
        "{self.base_url}?zip=10001&startYear=2010&endYear=2020&makeCode=BMW&makeCode=FORD&listingType=USED&mileage=50000"

        Based on the user needs, format the response as only the complete URL (no extra explanations).
        """
        
    def set_filters_from_llm_response(self, llm_response: str):
        """
        Process the LLM's response and set the URL with the provided parameters.
        """
        # Validate and set the URL from LLM's response
        if llm_response.startswith(self.base_url):
            self.url = llm_response.strip()
        else:
            raise ValueError("Invalid URL format provided by LLM response: " + llm_response)

# %%
if __name__ == "__main__":
    import nest_asyncio
    nest_asyncio.apply()

    interface = AutotraderInterface()
    interface.url = "https://www.autotrader.com/cars-for-sale/ford/new-york-ny?mileage=4000&zip=10001"

    listings = asyncio.run(interface.crawl())
# Out:
# Found the following car listings:
# {'title': 'Used 2023 Ford Bronco Raptor', 'url': '/cars-for-sale/vehicle/722672626?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '280 miles', 'price': '75,000', 'dealer': 'Land Rover Parsippany', 'phone': '(862) 420-3351', 'image': 'https://images.autotrader.com/scaler/408/306/hn/c/ecf342d8606a4b6b862893ac32f28a10.jpg'}
# {'title': 'Used 2023 Ford E-Transit 148" High Roof Extended', 'url': '/cars-for-sale/vehicle/722051013?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '39 miles', 'price': '39,995', 'dealer': 'Tasca Ford Mazda Subaru', 'phone': '(914) 515-2082', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/261df47c8e424ea994f67e2f1c7c01f4.jpg'}
# {'title': 'Used 2024 Ford Explorer XLT', 'url': '/cars-for-sale/vehicle/729651000?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '3,075 miles', 'price': '39,995', 'dealer': 'Tasca Ford Mazda Subaru', 'phone': '(914) 515-2082', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/c7fc7b1d79ed47328482049e8512cc65.jpg'}
# {'title': 'Used 2022 Ford EcoSport SE', 'url': '/cars-for-sale/vehicle/647948119?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '1,748 miles', 'price': '18,695', 'dealer': 'Biener Ford', 'phone': '(516) 201-2994', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/1b6977e5a426405c8b9b4d3b23a0a366.jpg'}
# {'title': 'Used 2022 Ford EcoSport SES', 'url': '/cars-for-sale/vehicle/648114059?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '1,632 miles', 'price': '19,595', 'dealer': 'Biener Ford', 'phone': '(516) 201-2994', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/eb7edc31917a4c638434ff4616a781ca.jpg'}
# {'title': 'Used 2024 Ford Mustang Mach-E Premium', 'url': '/cars-for-sale/vehicle/718039847?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '15 miles', 'price': '53,895', 'dealer': 'Biener Ford', 'phone': '(516) 201-2994', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/c7899359c1534d0f9145603fda5e7f12.jpg'}
# {'title': 'Used 2023 Ford F150 Lightning 4x4 SuperCrew', 'url': '/cars-for-sale/vehicle/729547536?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '1,267 miles', 'price': '40,900', 'dealer': 'BM Motor Cars', 'phone': '(908) 275-5090', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/0ee0108041994277aebba955f704761e.jpg'}
# {'title': 'Used 2023 Ford Bronco Raptor', 'url': '/cars-for-sale/vehicle/727988796?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '2,754 miles', 'price': '77,777', 'dealer': 'Rockville Centre GMC', 'phone': '(516) 786-4032', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/ee11b615557d4a6791fc31115f8b6326.jpg'}
# {'title': 'Used 2024 Ford F150 Raptor', 'url': '/cars-for-sale/vehicle/716998232?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '225 miles', 'price': '87,895', 'dealer': 'Manhattan Motorcars', 'phone': '(646) 568-4752', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/771b623fca554105a57298b25cdccfd7.jpg'}
# {'title': 'Used 2024 Ford Bronco Sport Big Bend', 'url': '/cars-for-sale/vehicle/707304257?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '3,886 miles', 'price': '30,495', 'dealer': 'Biener Ford', 'phone': '(516) 201-2994', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/27a463e523f74970a5f9757d960b8b07.jpg'}
# {'title': 'Used 2023 Ford F150 XL', 'url': '/cars-for-sale/vehicle/727838004?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '630 miles', 'price': '38,500', 'dealer': 'Liccardi Ford Lincoln', 'phone': '(908) 633-4449', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/9e6cd9d616e04d87bd3b7a8ff8788eb1.jpg'}
# {'title': 'Used 2024 Ford Escape Active', 'url': '/cars-for-sale/vehicle/730089274?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '3,972 miles', 'price': '31,025', 'dealer': 'Levittown Ford', 'phone': '(516) 246-6051', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/eff46565405a4a26b029c30c520381da.jpg'}
# {'title': 'Used 2023 Ford Ranger Lariat', 'url': '/cars-for-sale/vehicle/732005814?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '3,730 miles', 'price': '40,500', 'dealer': 'Performance Ford of East Hanover', 'phone': '(862) 701-2714', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/8696d6a44daa4b3eb30db2cc25885a85.jpg'}
# {'title': 'Used 2023 Ford E-Transit Medium Roof', 'url': '/cars-for-sale/vehicle/731007038?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '23 miles', 'price': '34,395', 'dealer': 'Tasca Ford Mazda Subaru', 'phone': '(914) 515-2082', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/91a65a41cf4a44c4a4965949afc12c88.jpg'}
# {'title': 'Used 2023 Ford E-Transit Medium Roof', 'url': '/cars-for-sale/vehicle/731007033?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '19 miles', 'price': '34,395', 'dealer': 'Tasca Ford Mazda Subaru', 'phone': '(914) 515-2082', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/dd5deed1057f4744b0645e301ce5abb4.jpg'}
# {'title': 'Used 2023 Ford Edge SE', 'url': '/cars-for-sale/vehicle/721106654?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '3,928 miles', 'price': '29,895', 'dealer': 'Biener Ford', 'phone': '(516) 201-2994', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/29acd7f962394c12b56dbe87a2ef7c10.jpg'}
# {'title': 'Used 2023 Ford F150 XLT', 'url': '/cars-for-sale/vehicle/704166117?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '99 miles', 'price': '50,888', 'dealer': 'MajorWorld.com', 'phone': '(347) 537-2593', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/52d395d225ee454b8138c5f8cf8a2bce.jpg'}
# {'title': 'Used 2024 Ford F150 XLT', 'url': '/cars-for-sale/vehicle/731418153?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '22 miles', 'price': '54,800', 'dealer': 'MajorWorld.com', 'phone': '(347) 537-2593', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/900612297adf4000bf604647a011c5ed.jpg'}
# {'title': 'Certified 2023 Ford Escape Active', 'url': '/cars-for-sale/vehicle/732181706?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '3,775 miles', 'price': '28,500', 'dealer': 'Dana Ford Lincoln', 'phone': '(929) 895-3718', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/0e6def8b319147aaa8497530ddd9af69.jpg'}
# {'title': 'Used 2022 Ford Transit Connect XL', 'url': '/cars-for-sale/vehicle/730693621?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '3,450 miles', 'price': '35,700', 'dealer': 'Private Seller Exchange', 'phone': None, 'image': 'https://images.autotrader.com/resize/304x228/ps-vehicle-media/677cde4a-6d1d-4605-a259-139b1e6ad85d.jpeg'}
# {'title': 'Used 2023 Ford Edge SE', 'url': '/cars-for-sale/vehicle/708900730?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '3,106 miles', 'price': '33,888', 'dealer': 'Ford Lincoln of Queens Boulevard', 'phone': '(332) 241-6804', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/44bfefc767c14c71a1def3fff7a8d187.jpg'}
# {'title': 'Used 2024 Ford Edge SEL', 'url': '/cars-for-sale/vehicle/710557242?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '2,157 miles', 'price': '37,356', 'dealer': 'Ford Lincoln of Queens Boulevard', 'phone': '(332) 241-6804', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/c11a83611e2e4857971031c7190c3636.jpg'}
# {'title': 'Certified 2022 Ford Explorer XLT', 'url': '/cars-for-sale/vehicle/730127045?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '3,472 miles', 'price': '37,500', 'dealer': 'Ford Lincoln of Queens Boulevard', 'phone': '(332) 241-6804', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/97f0f854bca5441fa74201d3a1cdc3be.jpg'}
# {'title': 'Used 2024 Ford Edge ST-Line', 'url': '/cars-for-sale/vehicle/710557234?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '3,199 miles', 'price': '38,499', 'dealer': 'Ford Lincoln of Queens Boulevard', 'phone': '(332) 241-6804', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/0217808bc6504b71b68bc19c00c1d5bf.jpg'}
# {'title': 'Used 2023 Ford Explorer ST', 'url': '/cars-for-sale/vehicle/731162764?city=New%20York&listingType=USED&makeCode=FORD&mileage=4000&newSearch=false&referrer=%2Fford%2Fnew-york-ny%3Fmileage%3D4000%26zip%3D10001&state=NY&zip=10001&clickType=listing', 'mileage': '3,164 miles', 'price': '51,995', 'dealer': 'Ford Lincoln of Queens Boulevard', 'phone': '(332) 241-6804', 'image': 'https://images.autotrader.com/scaler/304/228/hn/c/88c6ba561ecd4ae9a24ffc82c882cac6.jpg'}
