# %% [markdown]
# # Secret Agents: A Self-Healing Codebase Agentic Workflow

# %% [markdown]
# ## Overview
# This code implements a workflow-based error detection and correction system that combines LangGraph, LLM capabilities, and vector database technology to detect runtime errors, generate fixes, and maintain a memory of bug patterns. The system takes function definitions and runtime arguments, processes them through a graph-based workflow, and maintains a hierarchical error management system enriched by vector-based similarity search.

# %% [markdown]
# ## Motivation
# Several key factors motivate this implementation:
#
# 1. **Automated Error Resolution**
#    - Manual debugging is time-consuming and error-prone
#    - Automated fix generation streamlines the correction process
#    - LLMs can provide context-aware code repairs
#
# 2. **Pattern-Based Learning**
#    - Vector databases enable similarity-based bug pattern recognition
#    - Previous fixes can inform future error resolution
#    - Semantic search capabilities improve fix relevance
#
# 3. **Structured Bug Knowledge**
#    - Vector embeddings capture semantic relationships between errors
#    - ChromaDB enables efficient storage and retrieval of bug patterns
#    - Hierarchical error categorization through vector spaces
#
# 4. **Runtime Code Modification**
#    - Safe deployment of generated fixes
#    - State tracking during modifications
#    - Validation of applied patches

# %% [markdown]
# ## Key Components
# 1. **State Management System**:
#    - Maintains workflow state using Pydantic models
#    - Tracks function references, errors, and fixes
#    - Ensures type safety and execution validation
#
# 2. **LLM Integration**:
#    - Leverages LLM for code analysis and generation
#    - Produces fixes based on error types:
#      - Runtime Errors
#      - Logic Errors
#      - Type Errors
#      - Resource Errors
#
# 3. **Vector-Based Memory System**:
#    - Uses ChromaDB for efficient storage
#    - Enables semantic search of bug patterns
#    - Maintains contextual relationships between errors
#    - Supports pattern-based learning
#
# 4. **Graph-based Workflow**:
#    - Uses LangGraph's StateGraph for orchestration
#    - Implements error detection nodes
#    - Controls fix generation through edges

# %% [markdown]
# ## Vector Databases and ChromaDB
#
# ### What is a Vector Database?
# A vector database is specialized storage system designed to handle high-dimensional vectors, which are mathematical representations of data points. These vectors capture semantic meaning, making them ideal for:
# - Similarity search operations
# - Pattern recognition
# - Semantic relationships
# - Nearest neighbor queries
#
# ### Why Vector DBs Matter for ML
# Vector databases are crucial for modern ML systems because they:
# 1. Enable semantic search capabilities
# 2. Support efficient similarity computations
# 3. Scale well with large datasets
# 4. Maintain context and relationships
# 5. Facilitate pattern recognition
#
# ### ChromaDB Implementation
# ChromaDB provides a lightweight, embedded vector database that offers:
# 1. Simple API:
# ```python
# chroma_client = chromadb.Client()
# collection = chroma_client.create_collection(name='bug-reports')
# ```
#
# 2. Easy Data Management:
# ```python
# # Adding documents
# collection.add(
#     ids=[id],
#     documents=[document],
# )
#
# # Querying
# results = collection.query(
#     query_texts=[query],
#     n_results=10
# )
# ```
#
# 3. Automatic embedding generation
# 4. Efficient similarity search
# 5. Zero configuration requirements

# %% [markdown]
# ## Memory Architecture
# The system implements a sophisticated memory architecture:
#
# 1. **Vector Storage**:
#    - Bug reports converted to embeddings
#    - Semantic relationships preserved
#    - Efficient similarity search
#
# 2. **Pattern Recognition**:
#    - Similar bugs identified through vector similarity
#    - Historical fixes inform new solutions
#    - Pattern evolution tracked over time
#
# 3. **Memory Updates**:
#    - New patterns integrated into existing knowledge
#    - Related patterns merged and refined
#    - Obsolete patterns pruned

# %% [markdown]
# ## Visual Overview
# A flowchart representing the design and flow of the workflow.

# %% [markdown]
# <div style="max-width:600px;">
#
# ![image.png](../images/self_healing_code.png)
#
# </div>

# %% [markdown]
# ## Conclusion
# This implementation demonstrates a practical approach to automated code healing, enhanced by vector database technology. The system combines graph-based workflow management with LLM capabilities and vector-based pattern recognition, allowing for structured error correction while maintaining clear process control.
#
# Key advantages include:
# - Automated error detection and correction
# - Semantic pattern recognition
# - Efficient similarity-based search
# - Safe runtime code modification
#
# Future improvements could focus on:
# - Enhanced embedding strategies
# - Multi-modal pattern recognition
# - Distributed vector storage
# - Advanced pattern evolution tracking
#
# This system provides a foundation for building more sophisticated self-healing systems, particularly in applications requiring runtime error correction and pattern learning, with the added benefit of efficient vector-based memory management through ChromaDB.

# %% [markdown]
# # Dependencies and Imports
# Install dependencies and import libraries.

# %%
# %%capture

# !pip install langgraph
# !pip install langgraph-sdk
# !pip install langgraph-checkpoint-sqlite
# !pip install langchain-community
# !pip install langchain-core
# !pip install langchain-openai
# !pip install chromadb

# %%
from langchain_core.prompts import ChatPromptTemplate
from langgraph.graph import StateGraph, END
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI

import chromadb

from pydantic import BaseModel
from typing import Optional, Callable

import uuid
import json
import os
import types
import inspect
from dotenv import load_dotenv
import sys

# %% [markdown]
# ## Clients
# Import API keys and instantiate clients.

# %%
from pathlib import Path
for p in [Path.cwd() / '.env', Path.cwd() / '../.env', Path.cwd() / '../../.env']:
    if p.exists():
        load_dotenv(dotenv_path=p)
        break
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY') or os.getenv('GROQ_API_KEY', '')
llm = ChatOpenAI(model=os.getenv('GROQ_MODEL', 'llama-3.1-8b-instant'), base_url='https://api.groq.com/openai/v1')

chroma_client = chromadb.Client()
collection = chroma_client.get_or_create_collection(name='bug-reports')

# %% [markdown]
# ## Define Agent State
# We'll define the state that our agent will maintain throughout its operation.

# %%
class State(BaseModel):
    function: Callable
    function_string: str
    arguments: list
    error: bool
    error_description: str = ''
    new_function_string: str = ''
    bug_report: str = ''
    memory_search_results: list = []
    memory_ids_to_update: list = []

# %% [markdown]
# ## Define Code Healing Node Functions
# Now we'll define the code healing node functions that our agent will use: code_execution_node, code_update_node and code_patching_node.

# %%
def code_execution_node(state: State):
    ''' Run Arbitrary Code '''
    try:
        print('\nRunning Arbitrary Function')
        print('--------------------------\n')
        result = state.function(*state.arguments)
        print('\n✅ Arbitrary Function Ran Without Error')
        print(f'Result: {result}')
        print('---------------------------------------\n')
    except Exception as e:
        print(f'❌ Function Raised an Error: {e}')
        state.error = True
        state.error_description = str(e)
    return state


def code_update_node(state: State):
    ''' Update Arbitratry Code '''
    prompt = ChatPromptTemplate.from_template(
        'You are tasked with fixing a Python function that raised an error.'
        'Function: {function_string}'
        'Error: {error_description}' 
        'You must provide a fix for the present error only.'
        'The bug fix should handle the thrown error case gracefully by returning an error message.'
        'Do not raise an error in your bug fix.'
        'The function must use the exact same name and parameters.'
        'Your response must contain only the function definition with no additional text.'
        'Your response must not contain any additional formatting, such as code delimiters or language declarations.'
    )
    message = HumanMessage(content=prompt.format(function_string=state.function_string, error_description=state.error_description))
    new_function_string = llm.invoke([message]).content.strip()

    print('\n🐛 Buggy Function')
    print('-----------------\n')
    print(state.function_string)
    print('\n🩹 Proposed Bug Fix')
    print('-------------------\n')
    print(new_function_string)
    
    state.new_function_string = new_function_string
    return state


def code_patching_node(state: State):
    ''' Fix Arbitrary Code '''
    try:
        print('\n*******************')
        print('\n❤️‍🩹 Patching code...')
        # Store the new function as a string
        new_code = state.new_function_string
        
        # Create namespace for new function
        namespace = {}
        
        # Execute new code in namespace
        exec(new_code, namespace)
        
        # Get function name dynamically
        func_name = state.function.__name__
        
        # Get the new function using dynamic name
        new_function = namespace[func_name]
        
        # Update state
        state.function = new_function
        state.error = False

        # Test the new function
        result = state.function(*state.arguments)

        print('...patch complete 😬\n')
                
    except Exception as e:
        print(f'...patch failed: {e}')
        print(f'Error details: {str(e)}')

    print('******************\n')
    return state

# %% [markdown]
# ## Define Bug Reporting Node Functions
# Now we'll define the bug reporting node functions that our agent will use: bug_report_node, memory_search_node, memory_generation_node and memory_modification_node.

# %%
def bug_report_node(state: State):
    ''' Generate Bug Report '''
    prompt = ChatPromptTemplate.from_template(
        'You are tasked with generating a bug report for a Python function that raised an error.'
        'Function: {function_string}'
        'Error: {error_description}'
        'Your response must be a comprehensive string including only crucial information on the bug report'
    )
    message = HumanMessage(content=prompt.format(function_string=state.function_string, error_description=state.error_description))
    bug_report = llm.invoke([message]).content.strip()

    print('\n📝 Generating Bug Report')
    print('------------------------\n')
    print(bug_report)

    state.bug_report = bug_report
    return state


# Digest the bug report using the same template used when saving bug reports to increase the accuracy and relevance of results when querying the vector database.
def memory_search_node(state: State):
    ''' Find memories relevant to the current bug report '''
    prompt = ChatPromptTemplate.from_template(
        'You are tasked with archiving a bug report for a Python function that raised an error.'
        'Bug Report: {bug_report}.'
        'Your response must be a concise string including only crucial information on the bug report for future reference.'
        'Format: # function_name ## error_description ### error_analysis'
    )
    
    message = HumanMessage(content=prompt.format(
        bug_report=state.bug_report,
    ))
    
    response = llm.invoke([message]).content.strip()

    results = collection.query(query_texts=[response])

    print('\n🔎 Searching bug reports...')
    if results['ids'][0]:
        print(f'...{len(results["ids"][0])} found.\n')
        print(results)
        state.memory_search_results = [{'id':results['ids'][0][index], 'memory':results['documents'][0][index], 'distance':results['distances'][0][index]} for index, id in enumerate(results['ids'][0])]
    else:
        print('...none found.\n')
            
    return state


# Filter the top 30% of results to ensure the relevance of memories being updated.
def memory_filter_node(state: State):
    print('\n🗑️ Filtering bug reports...')
    for memory in state.memory_search_results:
        if memory['distance'] < 0.3:
            state.memory_ids_to_update.append(memory['id'])
        
    if state.memory_ids_to_update:
        print(f'...{len(state.memory_ids_to_update)} selected.\n')
    else:
        print('...none selected.\n')
            
    return state


# Condense the bug report before storing it in the vector database.
def memory_generation_node(state: State):
    ''' Generate relevant memories based on new bug report '''
    prompt = ChatPromptTemplate.from_template(
        'You are tasked with archiving a bug report for a Python function that raised an error.'
        'Bug Report: {bug_report}.'
        'Your response must be a concise string including only crucial information on the bug report for future reference.'
        'Format: # function_name ## error_description ### error_analysis'
    )
    
    message = HumanMessage(content=prompt.format(
        bug_report=state.bug_report,
    ))
    
    response = llm.invoke([message]).content.strip()

    print('\n💾 Saving Bug Report to Memory')
    print('------------------------------\n')
    print(response)

    id = str(uuid.uuid4())
    collection.add(
        ids=[id],
        documents=[response],
    )        
    return state


# Use the prior memory as well as the current bug report to generate an updated version of it.
def memory_modification_node(state: State):
    ''' Modify relevant memories based on new interaction '''
    prompt = ChatPromptTemplate.from_template(
        'Update the following memories based on the new interaction:'
        'Current Bug Report: {bug_report}'
        'Prior Bug Report: {memory_to_update}'
        'Your response must be a concise but cumulative string including only crucial information on the current and prior bug reports for future reference.'
        'Format: # function_name ## error_description ### error_analysis'
    )
    memory_to_update_id = state.memory_ids_to_update.pop(0)
    state.memory_search_results.pop(0)
    results = collection.get(ids=[memory_to_update_id])
    memory_to_update = results['documents'][0]
    message = HumanMessage(content=prompt.format(
        bug_report=state.bug_report,
        memory_to_update=memory_to_update,
    ))
    
    response = llm.invoke([message]).content.strip()
    
    print('\nCurrent Bug Report')
    print('------------------\n')
    print(memory_to_update)
    print('\nWill be Replaced With')
    print('---------------------\n')
    print(response)
    
    collection.update(
        ids=[memory_to_update_id],
        documents=[response],
    )
        
    return state

# %% [markdown]
# ## Define Edge Functions
# Now we'll define the conditional edge function that our agent will use to control the workflow.

# %%
def error_router(state: State):
    if state.error:
        return 'bug_report_node'
    else:
        return END

def memory_filter_router(state: State):
    if state.memory_search_results:
        return 'memory_filter_node'
    else:
        return 'memory_generation_node'


def memory_generation_router(state: State):
    if state.memory_ids_to_update:
        return 'memory_modification_node'
    else:
        return 'memory_generation_node'


def memory_update_router(state: State):
    if state.memory_ids_to_update:
        return 'memory_modification_node'
    else:
        return 'code_update_node'

# %% [markdown]
# ## Build Workflow
# Now we'll create our workflow and compile it.

# %%
builder = StateGraph(State)

# Add nodes to the graph
builder.add_node('code_execution_node', code_execution_node)
builder.add_node('code_update_node', code_update_node)
builder.add_node('code_patching_node', code_patching_node)
builder.add_node('bug_report_node', bug_report_node)
builder.add_node('memory_search_node', memory_search_node)
builder.add_node('memory_filter_node', memory_filter_node)
builder.add_node('memory_modification_node', memory_modification_node)
builder.add_node('memory_generation_node', memory_generation_node)


# Add edges to the graph
# NOTE: explicit path_map dicts are required so the visualization renders all edges
builder.set_entry_point('code_execution_node')
builder.add_conditional_edges(
    'code_execution_node', error_router,
    {'bug_report_node': 'bug_report_node', END: END}
)
builder.add_edge('bug_report_node', 'memory_search_node')
builder.add_conditional_edges(
    'memory_search_node', memory_filter_router,
    {'memory_filter_node': 'memory_filter_node', 'memory_generation_node': 'memory_generation_node'}
)
builder.add_conditional_edges(
    'memory_filter_node', memory_generation_router,
    {'memory_modification_node': 'memory_modification_node', 'memory_generation_node': 'memory_generation_node'}
)
builder.add_edge('memory_generation_node', 'code_update_node')
builder.add_conditional_edges(
    'memory_modification_node', memory_update_router,
    {'memory_modification_node': 'memory_modification_node', 'code_update_node': 'code_update_node'}
)

builder.add_edge('code_update_node', 'code_patching_node')
builder.add_edge('code_patching_node', 'code_execution_node')

# Compile the graph
graph = builder.compile()

# Visualize the full graph structure
try:
    from IPython.display import Image, display
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception as e:
    print(f'Visualization failed: {e}')
    print('Install optional deps: pip install pygraphviz')

# %% [markdown]
# # Main Function
# Define the function that runs the instanciates the workflow and its state.

# %%
def execute_self_healing_code_system(function, arguments):

    state = State(
        error=False,
        function=function,
        function_string=inspect.getsource(function),
        arguments=arguments,
    )
    
    return graph.invoke(state)

# %% [markdown]
# # Run Program
# Instanciate the main function and observe outputs.

# %%
# Test Function 1: List Processing
def process_list(lst, index):
    return lst[index] * 2

# Test Function 2: String Parsing
def parse_date(date_string):
    year, month, day = date_string.split('-')
    return {'year': int(year), 'month': int(month), 'day': int(day)}

# Original division function
def divide_two_numbers(a, b):
    return a/b

# Test Cases
print("*******************************")
print("*******************************")
print("** Testing Division Function **")
print("*******************************")
print("*******************************")
execute_self_healing_code_system(divide_two_numbers, [10, 0]);
execute_self_healing_code_system(divide_two_numbers, ['a', 0]);

print("**************************************")
print("**************************************")
print("** Testing List Processing Function **")
print("**************************************")
print("**************************************")
# Test 1: Index out of range
execute_self_healing_code_system(process_list, [[1, 2, 3], 5]);
# Test 2: Invalid input type
execute_self_healing_code_system(process_list, [None, 1]);

print("***********************************")
print("***********************************")
print("** Testing Date Parsing Function **")
print("***********************************")
print("***********************************")
# Test 1: Invalid format
execute_self_healing_code_system(parse_date, ["2024/01/01"]);
# Test 2: Invalid data types
execute_self_healing_code_system(parse_date, ["abc-def-ghi"]);
# Out:
# *******************************
# *******************************
# ** Testing Division Function **
# *******************************
# *******************************
#
# Running Arbitrary Function
# --------------------------
#
# ❌ Function Raised an Error: division by zero
#
# 📝 Generating Bug Report
# ------------------------
#
# **Bug Report**
#
# **Function Name:** divide_two_numbers
# **Error Type:** division by zero
# **Error Message:** division by zero
#
# **Description:**
# The `divide_two_numbers` function returns the result of dividing two input numbers, `a` and `b`. However, it does not handle the case where `b` is zero, resulting in a division by zero error.
#
# **Steps to Reproduce:**
#
# 1. Call the `divide_two_numbers` function with `a = 10` and `b = 0`.
#
# **Code Snippet:**
# ```python
# def divide_two_numbers(a, b):
#     return a/b
# ```
# **Error Location:** Line 2, `return a/b`
#
# **Expected Behavior:** The function should raise a `ZeroDivisionError` with a clear error message indicating that division by zero is not allowed.
# **Actual Behavior:** The function raises a `ZeroDivisionError` with the default error message "division by zero".
#
# **Recommendation:**
# To fix this bug, we can add input validation to ensure that `b` is not zero before performing the division. This can be achieved by raising a `ValueError` or a custom error if `b` is zero.
#
# Example fix:
# ```python
# def divide_two_numbers(a, b):
#     if b == 0:
#         raise ValueError("Cannot divide by zero")
#     return a/b
# ```
# **Version of Python:**
# Python 3.9
#
# **Operating System:**
# Windows 10
#
# 🔎 Searching bug reports...
# ...none found.
#
#
# 💾 Saving Bug Report to Memory
# ------------------------------
#
# **divide_two_numbers ## Division by Zero Error ### Error Analysis**
# - **Error Type**: division by zero
# - **Error Message**: division by zero
# - **Error Location**: Line 2, `return a/b`
# - **Recommendation**: Add input validation to ensure `b` is not zero before performing division.
# - **Fix Example**: Raise a `ValueError` if `b` is zero.
# ```python
# def divide_two_numbers(a, b):
#     if b == 0:
#         raise ValueError("Cannot divide by zero")
#     return a/b
# ```
#
# 🐛 Buggy Function
# -----------------
#
# def divide_two_numbers(a, b):
#     return a/b
#
#
# 🩹 Proposed Bug Fix
# -------------------
#
# def divide_two_numbers(a, b):
#     if b == 0:
#         return "Cannot divide by zero"
#     return a/b
#
# *******************
#
# ❤️‍🩹 Patching code...
# ...patch complete 😬
#
# ******************
#
#
# Running Arbitrary Function
# --------------------------
#
#
# ✅ Arbitrary Function Ran Without Error
# Result: Cannot divide by zero
# ---------------------------------------
#
#
# Running Arbitrary Function
# --------------------------
#
# ❌ Function Raised an Error: unsupported operand type(s) for /: 'str' and 'int'
#
# 📝 Generating Bug Report
# ------------------------
#
# **Bug Report:**
#
# **Function Name:** `divide_two_numbers`
# **Version:** Unknown
# **Error Message:** `unsupported operand type(s) for /: 'str' and 'int'`
#
# **Description:** The function `divide_two_numbers` is raising an exception when attempting to divide two values. The error occurs because the function is expecting two numeric types (`int` or `float`), but is receiving a mix of types (in this case, a string and an integer).
#
# **Steps to Reproduce:**
#
# 1. Call the function with two arguments, one of which is a string and the other is an integer. For example:
#    ```python
# print(divide_two_numbers('5', 2))
# ```
#
# **Expected Behavior:** The function should return the result of dividing the two values. For example, in the above case, it should return a float value of `2.5`.
#
# **Actual Behavior:** The function raises an exception of type `TypeError` with the message `unsupported operand type(s) for /: 'str' and 'int'`.
#
# **Recommendation:** Modify the function to check the types of the inputs before attempting to divide them. This can be done using a simple `if` statement to check that both inputs are numbers.
#
# **Example of Fixed Function:**
#
# ```python
# def divide_two_numbers(a, b):
#     if isinstance(a, (int, float)) and isinstance(b, (int, float)):
#         return a / b
#     else:
#         raise ValueError("Both inputs must be numbers")
# ```
#
# This revised function will check that both inputs are numbers before attempting to divide them, and raise a `ValueError` exception if either input is not a number.
#
# 🔎 Searching bug reports...
# ...1 found.
#
# {'ids': [['ee81cbf7-c99e-4193-be19-1f6cb1108271']], 'embeddings': None, 'documents': [['**divide_two_numbers ## Division by Zero Error ### Error Analysis**\n- **Error Type**: division by zero\n- **Error Message**: division by zero\n- **Error Location**: Line 2, `return a/b`\n- **Recommendation**: Add input validation to ensure `b` is not zero before performing division. \n- **Fix Example**: Raise a `ValueError` if `b` is zero. \n```python\ndef divide_two_numbers(a, b):\n    if b == 0:\n        raise ValueError("Cannot divide by zero")\n    return a/b\n```']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None]], 'distances': [[0.5438042879104614]]}
#
# 🗑️ Filtering bug reports...
# ...none selected.
#
#
# 💾 Saving Bug Report to Memory
# ------------------------------
#
# # **divide_two_numbers**
#
# ## unsupported operand type(s) for /: 'str' and 'int'
#
# ### Error Analysis:
#
# * Unexpected mix of data types for division operation (string and integer).
# * Function requires both inputs to be numeric (int or float) for division to occur.
# * Introduced a type check using `isinstance()` to validate input data types before executing the division operation.
#
# 🐛 Buggy Function
# -----------------
#
# def divide_two_numbers(a, b):
#     return a/b
#
#
# 🩹 Proposed Bug Fix
# -------------------
#
# def divide_two_numbers(a, b):
#     try:
#         return a/b
#     except TypeError:
#         return "Error: unsupported operand type(s) for /: '{}' and '{}'".format(type(a), type(b))
#
# *******************
#
# ❤️‍🩹 Patching code...
# ...patch complete 😬
#
# ******************
#
#
# Running Arbitrary Function
# --------------------------
#
#
# ✅ Arbitrary Function Ran Without Error
# Result: Error: unsupported operand type(s) for /: '<class 'str'>' and '<class 'int'>'
# ---------------------------------------
#
# **************************************
# **************************************
# ** Testing List Processing Function **
# **************************************
# **************************************
#
# Running Arbitrary Function
# --------------------------
#
# ❌ Function Raised an Error: list index out of range
#
# 📝 Generating Bug Report
# ------------------------
#
# **Bug Report**
#
# **Function Name:** process_list
# **Module/Path:** (Module name not specified, assuming it's a local file)
# **Function Parameters:**
# - `lst`: The list being processed
# - `index`: The index of the list being accessed
# **Error Message:**
# - **list index out of range**
# **Error Description:**
# The function `process_list` raises a `list index out of range` error when the `index` provided is greater than or equal to the length of the list `lst`.
#
# **Steps to Reproduce:**
# 1. Call the `process_list(lst, index)` function where `index` is greater than or equal to the length of `lst`
#    Example: `process_list([1, 2, 3], 3)`
# 2. Observe the `list index out of range` error being raised
#
# **Expected Behavior:**
# The function should raise a meaningful error message or handle the situation where the `index` is out of range instead of raising a generic `list index out of range` error.
#
# **Recommendation:**
# Add a check in the function to ensure the `index` is within the bounds of the list before attempting to access it. If the `index` is out of range, return a meaningful error message or raise a custom exception.
#
# **Example of Fixed Code:**
# ```python
# def process_list(lst, index):
#     if index >= len(lst):
#         raise ValueError("Index out of range for the list")
#     return lst[index] * 2
# ```
#
# 🔎 Searching bug reports...
# ...2 found.
#
# {'ids': [['039f0d9d-a782-47eb-86b5-1f9662dad667', 'ee81cbf7-c99e-4193-be19-1f6cb1108271']], 'embeddings': None, 'documents': [["# **divide_two_numbers**\n \n## unsupported operand type(s) for /: 'str' and 'int'\n \n### Error Analysis:\n\n* Unexpected mix of data types for division operation (string and integer).\n* Function requires both inputs to be numeric (int or float) for division to occur.\n* Introduced a type check using `isinstance()` to validate input data types before executing the division operation.", '**divide_two_numbers ## Division by Zero Error ### Error Analysis**\n- **Error Type**: division by zero\n- **Error Message**: division by zero\n- **Error Location**: Line 2, `return a/b`\n- **Recommendation**: Add input validation to ensure `b` is not zero before performing division. \n- **Fix Example**: Raise a `ValueError` if `b` is zero. \n```python\ndef divide_two_numbers(a, b):\n    if b == 0:\n        raise ValueError("Cannot divide by zero")\n    return a/b\n```']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.392458200454712, 1.4664283990859985]]}
#
# 🗑️ Filtering bug reports...
# ...none selected.
#
#
# 💾 Saving Bug Report to Memory
# ------------------------------
#
# # process_list
# ## list index out of range error when index is greater than or equal to the list length
# ### Analysis: The function process_list raises a list index out of range error due to attempting to access an index that does not exist in the list. Adding a check to ensure the index is within the bounds of the list before accessing it resolves the issue. A ValueError with a meaningful message is raised if the index is out of range.
#
# 🐛 Buggy Function
# -----------------
#
# def process_list(lst, index):
#     return lst[index] * 2
#
#
# 🩹 Proposed Bug Fix
# -------------------
#
# def process_list(lst, index):
#     if index < len(lst):
#         return lst[index] * 2
#     else:
#         return "Error: list index out of range"
#
# *******************
#
# ❤️‍🩹 Patching code...
# ...patch complete 😬
#
# ******************
#
#
# Running Arbitrary Function
# --------------------------
#
#
# ✅ Arbitrary Function Ran Without Error
# Result: Error: list index out of range
# ---------------------------------------
#
#
# Running Arbitrary Function
# --------------------------
#
# ❌ Function Raised an Error: 'NoneType' object is not subscriptable
#
# 📝 Generating Bug Report
# ------------------------
#
# **Bug Report**
#
# **Function:** `process_list(lst, index)`
# **Error:** `TypeError: 'NoneType' object is not subscriptable`
# **Description:** The function `process_list(lst, index)` is raising an error when attempting to subscript a `None` object. This issue arises when the input `lst` does not have an element at the specified `index`.
#
# **Example:**
#
# ```python
# lst = None
# index = 0
# try:
#     print(process_list(lst, index))
# except TypeError as e:
#     print(f"Error: {e}")
# ```
#
# **Cause:** The function assumes that the input `lst` is a list with at least one element. However, when `lst` is `None`, the function attempts to subscript `None`, resulting in the error.
#
# **Expected Fix:** To resolve this issue, the function should check if `lst` is `None` before attempting to subscript it. A possible fix is:
#
# ```python
# def process_list(lst, index):
#     if lst is None:
#         return None  # or raise an exception
#     return lst[index] * 2
# ```
#
# **Severity:** Medium
#
# **Category:** Type Error
#
# **Priority:** High
#
# **Assigned to:** [Your Name]
#
# 🔎 Searching bug reports...
# ...3 found.
#
# {'ids': [['febef7c6-ecd0-4f31-9f8b-09e91efeb9f6', '039f0d9d-a782-47eb-86b5-1f9662dad667', 'ee81cbf7-c99e-4193-be19-1f6cb1108271']], 'embeddings': None, 'documents': [['# process_list\n## list index out of range error when index is greater than or equal to the list length\n### Analysis: The function process_list raises a list index out of range error due to attempting to access an index that does not exist in the list. Adding a check to ensure the index is within the bounds of the list before accessing it resolves the issue. A ValueError with a meaningful message is raised if the index is out of range.', "# **divide_two_numbers**\n \n## unsupported operand type(s) for /: 'str' and 'int'\n \n### Error Analysis:\n\n* Unexpected mix of data types for division operation (string and integer).\n* Function requires both inputs to be numeric (int or float) for division to occur.\n* Introduced a type check using `isinstance()` to validate input data types before executing the division operation.", '**divide_two_numbers ## Division by Zero Error ### Error Analysis**\n- **Error Type**: division by zero\n- **Error Message**: division by zero\n- **Error Location**: Line 2, `return a/b`\n- **Recommendation**: Add input validation to ensure `b` is not zero before performing division. \n- **Fix Example**: Raise a `ValueError` if `b` is zero. \n```python\ndef divide_two_numbers(a, b):\n    if b == 0:\n        raise ValueError("Cannot divide by zero")\n    return a/b\n```']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None, None]], 'distances': [[0.724848210811615, 1.329714059829712, 1.3836020231246948]]}
#
# 🗑️ Filtering bug reports...
# ...none selected.
#
#
# 💾 Saving Bug Report to Memory
# ------------------------------
#
# # process_list
# ## TypeError: 'NoneType' object is not subscriptable
# ### The bug arises when the input 'lst' is 'None' and the function attempts to subscript it without checking if 'lst' is 'None'. The function should be modified to check for 'None' before subscripting 'lst'.
#
# 🐛 Buggy Function
# -----------------
#
# def process_list(lst, index):
#     return lst[index] * 2
#
#
# 🩹 Proposed Bug Fix
# -------------------
#
# def process_list(lst, index):
#     if lst is None:
#         return "Error: list is None"
#     elif isinstance(index, type(None)):
#         return "Error: index is None"
#     try:
#         return lst[index] * 2
#     except IndexError:
#         return "Error: index out of range"
#
# *******************
#
# ❤️‍🩹 Patching code...
# ...patch complete 😬
#
# ******************
#
#
# Running Arbitrary Function
# --------------------------
#
#
# ✅ Arbitrary Function Ran Without Error
# Result: Error: list is None
# ---------------------------------------
#
# ***********************************
# ***********************************
# ** Testing Date Parsing Function **
# ***********************************
# ***********************************
#
# Running Arbitrary Function
# --------------------------
#
# ❌ Function Raised an Error: not enough values to unpack (expected 3, got 1)
#
# 📝 Generating Bug Report
# ------------------------
#
# **Bug Report**
#
# **Function Name:** `parse_date(date_string)`
# **Error Type:** `ValueError`
# **Error Message:** `not enough values to unpack (expected 3, got 1)`
#
# **Description:**
# The provided function `parse_date(date_string)` is attempting to split a date string into three parts (year, month, and day) using the '-' character as a delimiter. However, the error message indicates that the function is receiving only one value instead of the expected three.
#
# **Possible Cause:**
# The issue likely arises when the input `date_string` does not match the expected format 'YYYY-MM-DD'. For example, if the input is a date string with only the year or month and year, the split operation will result in fewer than three values.
#
# **Example Input:**
# - `date_string = '2022-01'` (Expected to raise the error)
# - `date_string = '2022-01-15'` (Expected to pass without errors)
#
# **Steps to Reproduce:**
# 1. Call the `parse_date(date_string)` function with a date string that does not match the 'YYYY-MM-DD' format.
#
# **Solution:**
# To resolve the issue, we need to add input validation to ensure that the date string is in the correct format. This can be achieved by checking the number of values returned from the `split()` method and raising a more informative error message.
#
# **Example Code** (Modified function):
#
# ```python
# def parse_date(date_string):
#     split_values = date_string.split('-')
#     if len(split_values) != 3:
#         raise ValueError("Invalid date format. Expected 'YYYY-MM-DD', got '{}'".format(date_string))
#     year, month, day = split_values
#     return {'year': int(year), 'month': int(month), 'day': int(day)}
# ```
#
# **Recommendations:**
# - Improve input validation to handle date string formats that do not match 'YYYY-MM-DD'.
# - Raise more informative error messages to assist in debugging and error resolution.
#
# 🔎 Searching bug reports...
# ...4 found.
#
# {'ids': [['039f0d9d-a782-47eb-86b5-1f9662dad667', 'ee81cbf7-c99e-4193-be19-1f6cb1108271', 'febef7c6-ecd0-4f31-9f8b-09e91efeb9f6', '82fe79e2-0a8b-4b75-8f73-18496a6a1c7d']], 'embeddings': None, 'documents': [["# **divide_two_numbers**\n \n## unsupported operand type(s) for /: 'str' and 'int'\n \n### Error Analysis:\n\n* Unexpected mix of data types for division operation (string and integer).\n* Function requires both inputs to be numeric (int or float) for division to occur.\n* Introduced a type check using `isinstance()` to validate input data types before executing the division operation.", '**divide_two_numbers ## Division by Zero Error ### Error Analysis**\n- **Error Type**: division by zero\n- **Error Message**: division by zero\n- **Error Location**: Line 2, `return a/b`\n- **Recommendation**: Add input validation to ensure `b` is not zero before performing division. \n- **Fix Example**: Raise a `ValueError` if `b` is zero. \n```python\ndef divide_two_numbers(a, b):\n    if b == 0:\n        raise ValueError("Cannot divide by zero")\n    return a/b\n```', '# process_list\n## list index out of range error when index is greater than or equal to the list length\n### Analysis: The function process_list raises a list index out of range error due to attempting to access an index that does not exist in the list. Adding a check to ensure the index is within the bounds of the list before accessing it resolves the issue. A ValueError with a meaningful message is raised if the index is out of range.', "# process_list\n## TypeError: 'NoneType' object is not subscriptable\n### The bug arises when the input 'lst' is 'None' and the function attempts to subscript it without checking if 'lst' is 'None'. The function should be modified to check for 'None' before subscripting 'lst'."]], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None, None, None]], 'distances': [[1.1349608898162842, 1.2652807235717773, 1.2821605205535889, 1.364391565322876]]}
#
# 🗑️ Filtering bug reports...
# ...none selected.
#
#
# 💾 Saving Bug Report to Memory
# ------------------------------
#
# ### parse_date
# #### ValueError: not enough values to unpack (expected 3, got 1)
#
# **Cause:** Input date string not matching expected 'YYYY-MM-DD' format.
# **Solution:** Added input validation to check the number of values returned from `split()` method and raise a more informative error message.
#
# 🐛 Buggy Function
# -----------------
#
# def parse_date(date_string):
#     year, month, day = date_string.split('-')
#     return {'year': int(year), 'month': int(month), 'day': int(day)}
#
#
# 🩹 Proposed Bug Fix
# -------------------
#
# def parse_date(date_string):
#     try:
#         year, month, day = date_string.split('-')
#         return {'year': int(year), 'month': int(month), 'day': int(day)}
#     except ValueError:
#         return {'error': 'Invalid date string, please use the format: YYYY-MM-DD'}
#
# *******************
#
# ❤️‍🩹 Patching code...
# ...patch complete 😬
#
# ******************
#
#
# Running Arbitrary Function
# --------------------------
#
#
# ✅ Arbitrary Function Ran Without Error
# Result: {'error': 'Invalid date string, please use the format: YYYY-MM-DD'}
# ---------------------------------------
#
#
# Running Arbitrary Function
# --------------------------
#
# ❌ Function Raised an Error: invalid literal for int() with base 10: 'abc'
#
# 📝 Generating Bug Report
# ------------------------
#
# **Bug Report:**
#
# **Function:** parse_date(date_string)
# **Error:** invalid literal for int() with base 10: 'abc'
# **Severity:** Critical
# **Description:**
# The parse_date function is designed to parse a date string in the format 'YYYY-MM-DD' and return a dictionary with 'year', 'month', and 'day' as keys.
#
# However, the function raises a ValueError when it encounters a non-numeric value in the date string, specifically when the date string contains non-numeric characters. This is because the function attempts to convert the day, month, or year to an integer using `int(year)`, `int(month)`, and `int(day)`, respectively, without any error handling.
#
# **Steps to reproduce the bug:**
#
# 1. Call the parse_date function with a date string containing non-numeric characters, such as '2022-12-abc'.
# 2. The function will raise a ValueError with the message 'invalid literal for int() with base 10: 'abc''
#
# **Expected behavior:**
#
# The function should handle non-numeric characters in the date string and raise a ValueError with a clear and descriptive error message.
#
# **Recommendations:**
#
# 1. Validate the input date string to ensure it contains only numeric characters.
# 2. Raise a ValueError with a clear and descriptive error message when the input date string contains non-numeric characters.
#
# **Example of a fixed parse_date function:**
#
# ```python
# def parse_date(date_string):
#     """
#     Parse a date string in the format 'YYYY-MM-DD' and return a dictionary with 'year', 'month', and 'day' as keys.
#
#     Args:
#         date_string (str): A date string in the format 'YYYY-MM-DD'.
#
#     Returns:
#         dict: A dictionary with 'year', 'month', and 'day' as keys.
#
#     Raises:
#         ValueError: If the input date string contains non-numeric characters.
#     """
#     try:
#         year, month, day = date_string.split('-')
#         if not year.isdigit() or not month.isdigit() or not day.isdigit():
#             raise ValueError("Invalid date string. Date string must contain only numeric characters.")
#         return {'year': int(year), 'month': int(month), 'day': int(day)}
#     except ValueError as e:
#         raise ValueError(f"Invalid date string: {date_string}") from e
# ```
#
# 🔎 Searching bug reports...
# ...5 found.
#
# {'ids': [['9f767767-7cfa-4fe3-8e96-2cb8c238478e', '039f0d9d-a782-47eb-86b5-1f9662dad667', 'ee81cbf7-c99e-4193-be19-1f6cb1108271', 'febef7c6-ecd0-4f31-9f8b-09e91efeb9f6', '82fe79e2-0a8b-4b75-8f73-18496a6a1c7d']], 'embeddings': None, 'documents': [["### parse_date\n#### ValueError: not enough values to unpack (expected 3, got 1)\n\n**Cause:** Input date string not matching expected 'YYYY-MM-DD' format.\n**Solution:** Added input validation to check the number of values returned from `split()` method and raise a more informative error message.", "# **divide_two_numbers**\n \n## unsupported operand type(s) for /: 'str' and 'int'\n \n### Error Analysis:\n\n* Unexpected mix of data types for division operation (string and integer).\n* Function requires both inputs to be numeric (int or float) for division to occur.\n* Introduced a type check using `isinstance()` to validate input data types before executing the division operation.", '**divide_two_numbers ## Division by Zero Error ### Error Analysis**\n- **Error Type**: division by zero\n- **Error Message**: division by zero\n- **Error Location**: Line 2, `return a/b`\n- **Recommendation**: Add input validation to ensure `b` is not zero before performing division. \n- **Fix Example**: Raise a `ValueError` if `b` is zero. \n```python\ndef divide_two_numbers(a, b):\n    if b == 0:\n        raise ValueError("Cannot divide by zero")\n    return a/b\n```', '# process_list\n## list index out of range error when index is greater than or equal to the list length\n### Analysis: The function process_list raises a list index out of range error due to attempting to access an index that does not exist in the list. Adding a check to ensure the index is within the bounds of the list before accessing it resolves the issue. A ValueError with a meaningful message is raised if the index is out of range.', "# process_list\n## TypeError: 'NoneType' object is not subscriptable\n### The bug arises when the input 'lst' is 'None' and the function attempts to subscript it without checking if 'lst' is 'None'. The function should be modified to check for 'None' before subscripting 'lst'."]], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None, None, None, None]], 'distances': [[0.4460454285144806, 0.987697422504425, 1.181035041809082, 1.3183726072311401, 1.3946391344070435]]}
#
# 🗑️ Filtering bug reports...
# ...none selected.
#
#
# 💾 Saving Bug Report to Memory
# ------------------------------
#
# # parse_date
# ## Function Raised ValueError with 'invalid literal for int() with base 10: 'abc''
# ### Bug Analysis
# - The function failed to handle non-numeric values in the input date string, specifically when the date string contains non-numeric characters.
# - The error arose from attempting to convert non-numeric values to integers using `int(year)`, `int(month)`, and `int(day)`.
# - A ValueError was raised with the default error message 'invalid literal for int() with base 10: 'abc''.
# - To fix the bug, input validation was added to ensure the date string contains only numeric characters, and a custom error message was raised upon encountering non-numeric characters.
#
# 🐛 Buggy Function
# -----------------
#
# def parse_date(date_string):
#     year, month, day = date_string.split('-')
#     return {'year': int(year), 'month': int(month), 'day': int(day)}
#
#
# 🩹 Proposed Bug Fix
# -------------------
#
# def parse_date(date_string):
#     try:
#         year, month, day = date_string.split('-')
#         if year.isdigit() and month.isdigit() and day.isdigit():
#             return {'year': int(year), 'month': int(month), 'day': int(day)}
#         else:
#             return 'Invalid date format. Date must be in YYYY-MM-DD.'
#     except Exception:
#         return 'Error parsing date. Please check the date format.'
#
# *******************
#
# ❤️‍🩹 Patching code...
# ...patch complete 😬
#
# ******************
#
#
# Running Arbitrary Function
# --------------------------
#
#
# ✅ Arbitrary Function Ran Without Error
# Result: Invalid date format. Date must be in YYYY-MM-DD.
# ---------------------------------------

# %% [markdown]
# ![](https://europe-west1-genai-agents-views-tracker.cloudfunctions.net/genai-agents-tracker?notebook=all-agents-tutorials--self-healing-code)
